# %% [markdown]
# ###Module for creating and training a neural network for handwritten digit recognition using the gradient descent method

# %%
from matplotlib import pyplot as plt

import network
import MNIST

# %matplotlib inline

# %%
train_data, valid_data, test_data = MNIST.get_dataset('./mnist.pkl.gz') #mnist_loader.

# %% [markdown]
# ##Train

# %%
net = network.Network([784, 30, 10])
net.SGD(train_data, 15, 10, 3.0, test_data=test_data)
# Out:
# time= 211.85350131988525
# accuracy= 90.57

# %%
net = network.Network([784, 30, 10])
net.SGD(train_data, 4, 10, 3.0, test_data=test_data)
# Out:
# time= 53.31908845901489
# accuracy= 85.05

# %%
net = network.Network([784, 30, 10])
net.SGD(train_data, 60, 10, 3.0, test_data=test_data)
# Out:
# time= 791.3459281921387
# accuracy= 92.43

# %%
train_data, valid_data, test_data = MNIST.get_dataset('./mnist.pkl.gz') #mnist_loader.
net = network.Network([784, 30, 10])
net.SGD(train_data, 15, 2, 3.0, test_data=test_data)
# Out:
# time= 204.30336713790894
# accuracy= 87.35000000000001

# %%
train_data, valid_data, test_data = MNIST.get_dataset('./mnist.pkl.gz') #mnist_loader.
net = network.Network([784, 30, 10])
net.SGD(train_data, 15, 20, 3.0, test_data=test_data)
# Out:
# time= 197.63389921188354
# accuracy= 91.3

# %%
train_data, valid_data, test_data = MNIST.get_dataset('./mnist.pkl.gz') #mnist_loader.
net = network.Network([784, 30, 10])
net.SGD(train_data, 15, 10, 0.5, test_data=test_data)
# Out:
# time= 192.1983573436737
# accuracy= 94.53

# %%
train_data, valid_data, test_data = MNIST.get_dataset('./mnist.pkl.gz') #mnist_loader.
net = network.Network([784, 30, 10])
net.SGD(train_data, 15, 10, 9, test_data=test_data)
# Out:
# time= 372.43342208862305
# accuracy= 19.12

# %%
train_data, valid_data, test_data = MNIST.get_dataset('./mnist.pkl.gz') #mnist_loader.
net = network.Network([784,78,30,10])
net.SGD(train_data, 15, 10, 3.0, test_data=test_data)

# %%
train_data, valid_data, test_data = MNIST.get_dataset('./mnist.pkl.gz') #mnist_loader.
net = network.Network([784,10])
net.SGD(train_data, 15, 10, 3.0, test_data=test_data)
# Out:
# time= 96.35455894470215
# accuracy= 71.57

# %%
net.save_weights()
# Out:
# C:\Users\nasta\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\numpy\core\_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# ##Test

# %%
net.load_weights('weights.npy')

image=MNIST.get_test_image('./mnist.pkl.gz')
plt.imshow(image)
plt.title("The figure shows the number {}".format(net.get_predict(image)))

plt.show()
