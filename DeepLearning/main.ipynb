# %% [markdown]
# ###Module for creating and training a neural network for handwritten digit recognition using the gradient descent method

# %%
from matplotlib import pyplot as plt

import network
import MNIST

# %matplotlib inline

# %%
train_data, valid_data, test_data = MNIST.get_dataset('./mnist.pkl.gz') #mnist_loader.

# %%
net = network.Network([784, 30, 10])

# %% [markdown]
# ##Train

# %%
net.SGD(train_data, 30, 10, 3.0, test_data=test_data)
# Out:
# <div id='11bc66aa-28cf-4376-9065-af5af4617451'></div>
# C:\Users\nasta\PycharmProjects\labs\ML\SUSU\DeepLearning\network.py:7: RuntimeWarning: overflow encountered in exp
#   return 1.0/(1.0+np.exp(-z))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 net.SGD(train_data, 30, 10, 3.0, test_data=test_data)
#
# File ~\PycharmProjects\labs\ML\SUSU\DeepLearning\network.py:90, in Network.SGD(self, train_data, epochs, bs, lr, test_data)
#      88 train_loader = self.DataLoader(train_data,bs)
#      89 for batch in train_loader:
# ---> 90   self.update_mini_batch(batch, lr)
#      92 self.log_accuracy.append((self.evaluate(test_data) / n_test) * 100)
#      93 self.plot_summary()
#
# File ~\PycharmProjects\labs\ML\SUSU\DeepLearning\network.py:72, in Network.update_mini_batch(self, batch, lr)
#      69 nabla_w = [np.zeros(w.shape) for w in self.weights] # list of dC/dw gradients for each layer
#      71 for x, y in batch:
# ---> 72   delta_nabla_b, delta_nabla_w = self.backprop(x, y)
#      73   nabla_b = [nb+dnb for nb, dnb in zip(nabla_b, delta_nabla_b)] # sum the gradients dC/db for different cases of the current subsample
#      74   nabla_w = [nw+dnw for nw, dnw in zip(nabla_w, delta_nabla_w)] #sum the gradients dC/dw for different cases of the current subsample
#
# File ~\PycharmProjects\labs\ML\SUSU\DeepLearning\network.py:61, in Network.backprop(self, x, y)
#      59 def backprop(self, x , y ):
#      60   self.forward(x)
# ---> 61   self.backward(y)
#      62   return (self.nabla_b, self.nabla_w)
#
# File ~\PycharmProjects\labs\ML\SUSU\DeepLearning\network.py:52, in Network.backward(self, y)
#      49 delta = np.dot(self.weights[-l+1].transpose(), delta) * sigmoid_prime(self.zs[-l]) #calculate the measure of the influence of neurons of the l-th layer on the magnitude of the error
#      51 self.nabla_b[-l] = delta # gradient dC/db for layer l
# ---> 52 self.nabla_w[-l] = np.dot(delta, self.activations[-l-1].transpose())
#
# File <__array_function__ internals>:5, in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
net.save_weights()
# Out:
# C:\Users\nasta\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\numpy\core\_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# ##Test

# %%
net.load_weights('weights.npy')

image=MNIST.get_test_image('./mnist.pkl.gz')
plt.imshow(image)
plt.title("The figure shows the number {}".format(net.get_predict(image)))

plt.show()
